# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

tf.__version__
# Out:
# '2.2.0-rc3'

# %%
# !wget --no-check-certificate \
    https://dicodingacademy.blob.core.windows.net/picodiploma/ml_pemula_academy/messy-vs-clean-room.zip \
    -O /tmp/messy_vs_clean_room.zip
# Out:
# --2020-05-03 14:30:38--  https://dicodingacademy.blob.core.windows.net/picodiploma/ml_pemula_academy/messy-vs-clean-room.zip
# Resolving dicodingacademy.blob.core.windows.net (dicodingacademy.blob.core.windows.net)... 52.239.197.36
# Connecting to dicodingacademy.blob.core.windows.net (dicodingacademy.blob.core.windows.net)|52.239.197.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70392746 (67M) [application/zip]
# Saving to: ‘/tmp/messy_vs_clean_room.zip’
#
# /tmp/messy_vs_clean 100%[===================>]  67.13M  99.7MB/s    in 0.7s
#
# 2020-05-03 14:30:38 (99.7 MB/s) - ‘/tmp/messy_vs_clean_room.zip’ saved [70392746/70392746]

# %%
from zipfile import ZipFile
import os

local_zip = '/tmp/messy_vs_clean_room.zip'

zip_ref = ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

base_dir = '/tmp/images'
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
# Out:
# ['clean', 'messy']

# %%
train_clean_dir = os.path.join(train_dir, 'clean')
train_messy_dir = os.path.join(train_dir, 'messy')

val_clean_dir = os.path.join(val_dir, 'clean')
val_messy_dir = os.path.join(val_dir, 'messy')

# %% [markdown]
# Create ImageDataGenerator

# %%
train_data_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    horizontal_flip=True,
    shear_range=0.2,
    fill_mode='nearest'
)

test_data_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    horizontal_flip=True,
    shear_range=0.2,
    fill_mode='nearest'
)

# %% [markdown]
# Prepare data train with ImageDataGenerator

# %%
train_generator = train_data_gen.flow_from_directory(
    train_dir,
    target_size=(150,150),
    batch_size=4,
    class_mode='binary'
)

val_generator = test_data_gen.flow_from_directory(
    val_dir,
    target_size=(150,150),
    batch_size=4,
    class_mode='binary'
)
# Out:
# Found 192 images belonging to 2 classes.
# Found 20 images belonging to 2 classes.

# %% [markdown]
# Build CNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),
    MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(
    loss='binary_crossentropy',
    optimizer=tf.optimizers.Adam(),
    metrics=['accuracy']
)

model.fit(
    train_generator,
    steps_per_epoch=25,
    epochs=20,
    validation_data=val_generator,
    validation_steps=5,
    verbose=2
)
# Out:
# Epoch 1/20
# 25/25 - 1s - loss: 0.7604 - accuracy: 0.4800 - val_loss: 0.6929 - val_accuracy: 0.5000
# Epoch 2/20
# 25/25 - 1s - loss: 0.6929 - accuracy: 0.5500 - val_loss: 0.6875 - val_accuracy: 0.5000
# Epoch 3/20
# 25/25 - 1s - loss: 0.6670 - accuracy: 0.5800 - val_loss: 0.7012 - val_accuracy: 0.4000
# Epoch 4/20
# 25/25 - 1s - loss: 0.7030 - accuracy: 0.5000 - val_loss: 0.6901 - val_accuracy: 0.6000
# Epoch 5/20
# 25/25 - 1s - loss: 0.6952 - accuracy: 0.5100 - val_loss: 0.6929 - val_accuracy: 0.5000
# Epoch 6/20
# 25/25 - 1s - loss: 0.7057 - accuracy: 0.6000 - val_loss: 0.6923 - val_accuracy: 0.5000
# Epoch 7/20
# 25/25 - 1s - loss: 0.7005 - accuracy: 0.4600 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 8/20
# 25/25 - 1s - loss: 0.6938 - accuracy: 0.5200 - val_loss: 0.6919 - val_accuracy: 0.5000
# Epoch 9/20
# 25/25 - 1s - loss: 0.6944 - accuracy: 0.4600 - val_loss: 0.6917 - val_accuracy: 0.5500
# Epoch 10/20
# 25/25 - 1s - loss: 0.6972 - accuracy: 0.5300 - val_loss: 0.6941 - val_accuracy: 0.4500
# Epoch 11/20
# 25/25 - 1s - loss: 0.6935 - accuracy: 0.4800 - val_loss: 0.6926 - val_accuracy: 0.5000
# Epoch 12/20
# 25/25 - 1s - loss: 0.6929 - accuracy: 0.5000 - val_loss: 0.6902 - val_accuracy: 0.6000
# Epoch 13/20
# 25/25 - 1s - loss: 0.6970 - accuracy: 0.5200 - val_loss: 0.6913 - val_accuracy: 0.5000
# Epoch 14/20
# 25/25 - 1s - loss: 0.6923 - accuracy: 0.5000 - val_loss: 0.6903 - val_accuracy: 0.5000
# Epoch 15/20
# 25/25 - 1s - loss: 0.6985 - accuracy: 0.5000 - val_loss: 0.6885 - val_accuracy: 0.6500
# Epoch 16/20
# 25/25 - 1s - loss: 0.7257 - accuracy: 0.5100 - val_loss: 0.6431 - val_accuracy: 0.7500
# Epoch 17/20
# 25/25 - 1s - loss: 0.6955 - accuracy: 0.4500 - val_loss: 0.6924 - val_accuracy: 0.5500
# Epoch 18/20
# 25/25 - 1s - loss: 0.7009 - accuracy: 0.5000 - val_loss: 0.6892 - val_accuracy: 0.5500
# Epoch 19/20
# 25/25 - 1s - loss: 0.6956 - accuracy: 0.4500 - val_loss: 0.6876 - val_accuracy: 0.6000
# Epoch 20/20
# 25/25 - 1s - loss: 0.6959 - accuracy: 0.5000 - val_loss: 0.6939 - val_accuracy: 0.4500

# %% [markdown]
# Ready to Test!
